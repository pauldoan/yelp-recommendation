# %% [markdown]
# # Final Project - Personalization Theory

# %% [markdown]
# Authors: *Bertrand Thia-Thiong-Fat, Jeremy Yao, Paul Doan*

# %% [markdown]
# In this notebook, we will implement a content-based model to predict the last ratings of the users in our dataset.

# %% [markdown]
# ## Loading the data

# %%
# Importing the libraries

import pandas as pd
from tqdm import tqdm
import json
import numpy as np
import sklearn.model_selection 
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity
import heapq

# %%
ratings = pd.read_csv('dataset.csv').drop(columns='Unnamed: 0')
ratings.head()
# Out:
#                   user_id             business_id  rating                 date
# 0  keBv05MsMFBd0Hu98vXThQ  JDZ6_yycNQFTpUZzLIKHUg     5.0  2018-11-14 18:05:34
# 1  hZ_ElhGO3sQDVvM8ZrQetA  zfyGTLKOZuVY8aRoInyx9Q     4.0  2018-11-14 17:59:07
# 2  y5zqSJE-rFihsKmUZRbbRg  evdJO0v9rvVixieNEnaeJg     5.0  2018-11-14 17:57:01
# 3  ozUsNrw9QlEtz_JqN5PlMw  u1fa8SE-Rzea_xWbk_B-Zw     3.0  2018-11-14 17:49:52
# 4  sHY6JcgWOHLP4vR836Esmw  urSuLlkYXXI5uwtKIxl9ew     5.0  2018-11-14 17:25:32

# %%
print('There are {} active users. \nThey add up to a total of {} unique ratings. \nThere are {} different businesses'.format(ratings["user_id"].nunique(), ratings.shape[0], ratings["business_id"].nunique()))
# Out:
# There are 30750 active users.
# They add up to a total of 317153 unique ratings.
# There are 4996 different businesses

# %% [markdown]
# # First Model: Content Based

# %% [markdown]
# The motivation behind this model is understanding the different sources of information available and weight the relevant features in our model. As a result, we will leverage this information and make predictions. In this study, we will use features about the different businesses at hand.

# %% [markdown]
# ## 1. Implementation

# %% [markdown]
# Let's take a look at our businesses attributes:

# %%
# Importing the business data
from tqdm import tqdm

business = pd.read_json('yelp_dataset/business.json', lines=True)
business = business[business['business_id'].isin(ratings['business_id'])]
business.set_index('business_id', inplace=True)
attributes = business.columns
business.head()
# Out:
#                                               address  \
# business_id
# jScBTQtdAt-8RshaiBEHgw  1770 W Horizon Ridge, Ste 100
# 6fPQJq4f_yiq1NHn0fd11Q          3655 Las Vegas Blvd S
# k-dDZvTeLysoJvjHI-qr9g              2411 W Sahara Ave
# MhnihE0alud0ereVInSt8Q  2765 N Scottsdale Rd, Ste 105
# i6hWP3si97eKQl_JyK8L3w          145 Richmond Street W
#
#                                                                attributes  \
# business_id
# jScBTQtdAt-8RshaiBEHgw  {'DriveThru': 'False', 'RestaurantsAttire': ''...
# 6fPQJq4f_yiq1NHn0fd11Q  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# k-dDZvTeLysoJvjHI-qr9g  {'RestaurantsDelivery': 'False', 'RestaurantsT...
# MhnihE0alud0ereVInSt8Q  {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# i6hWP3si97eKQl_JyK8L3w  {'RestaurantsPriceRange2': '3', 'WiFi': ''free...
#
#                                                                categories  \
# business_id
# jScBTQtdAt-8RshaiBEHgw  Ethnic Food, American (New), Burgers, Food, Re...
# 6fPQJq4f_yiq1NHn0fd11Q                     French, Restaurants, Creperies
# k-dDZvTeLysoJvjHI-qr9g                               Buffets, Restaurants
# MhnihE0alud0ereVInSt8Q                               Chinese, Restaurants
# i6hWP3si97eKQl_JyK8L3w  Hotels, Event Planning & Services, Hotels & Tr...
#
#                               city  \
# business_id
# jScBTQtdAt-8RshaiBEHgw   Henderson
# 6fPQJq4f_yiq1NHn0fd11Q   Las Vegas
# k-dDZvTeLysoJvjHI-qr9g   Las Vegas
# MhnihE0alud0ereVInSt8Q  Scottsdale
# i6hWP3si97eKQl_JyK8L3w     Toronto
#
#                                                                     hours  \
# business_id
# jScBTQtdAt-8RshaiBEHgw  {'Monday': '0:0-0:0', 'Tuesday': '9:0-15:0', '...
# 6fPQJq4f_yiq1NHn0fd11Q  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...
# k-dDZvTeLysoJvjHI-qr9g  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# MhnihE0alud0ereVInSt8Q  {'Monday': '11:0-21:30', 'Tuesday': '11:0-21:3...
# i6hWP3si97eKQl_JyK8L3w  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
#
#                         is_open   latitude   longitude  \
# business_id
# jScBTQtdAt-8RshaiBEHgw        1  36.010745 -115.064803
# 6fPQJq4f_yiq1NHn0fd11Q        1  36.112527 -115.171351
# k-dDZvTeLysoJvjHI-qr9g        1  36.142116 -115.174252
# MhnihE0alud0ereVInSt8Q        1  33.478754 -111.925484
# i6hWP3si97eKQl_JyK8L3w        1  43.649612  -79.385447
#
#                                                   name postal_code  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                          Served       89012
# 6fPQJq4f_yiq1NHn0fd11Q                     La Creperie       89109
# k-dDZvTeLysoJvjHI-qr9g                    Feast Buffet       89102
# MhnihE0alud0ereVInSt8Q  Yummy Yummy Chinese Restaurant       85257
# i6hWP3si97eKQl_JyK8L3w                  Hilton Toronto     M5H 2L2
#
#                         review_count  stars state
# business_id
# jScBTQtdAt-8RshaiBEHgw           664    4.5    NV
# 6fPQJq4f_yiq1NHn0fd11Q           535    3.5    NV
# k-dDZvTeLysoJvjHI-qr9g           287    3.0    NV
# MhnihE0alud0ereVInSt8Q           188    3.0    AZ
# i6hWP3si97eKQl_JyK8L3w           131    3.5    ON

# %% [markdown]
# Our assumption is that the study of the features of the different businesses help us understand the preferences of the users to drive insights and recommendations.

# %%
# Splitting for each single unique category
unique_category = []

for l in business['categories'].unique():
    for cat in l.split(', '):
        if cat not in unique_category:
            unique_category.append(cat)

# %%
# Creating category multidimensional space
for category in tqdm(unique_category):
    business[category] = 0
    for bus in business.index:
        if category in business.loc[bus, 'categories']:
            business.loc[bus, category] = 1
# Out:
# 100%|██████████| 758/758 [00:48<00:00, 15.58it/s]

# %%
# Creating the category matrix
categories = business.drop(attributes, axis=1)
business = business.drop(categories.columns, axis=1)
categories.head()
# Out:
#                         Ethnic Food  American (New)  Burgers  Food  \
# business_id
# jScBTQtdAt-8RshaiBEHgw            1               1        1     1
# 6fPQJq4f_yiq1NHn0fd11Q            0               0        0     0
# k-dDZvTeLysoJvjHI-qr9g            0               0        0     0
# MhnihE0alud0ereVInSt8Q            0               0        0     0
# i6hWP3si97eKQl_JyK8L3w            0               0        0     0
#
#                         Restaurants  Asian Fusion  Specialty Food  Mexican  \
# business_id
# jScBTQtdAt-8RshaiBEHgw            1             1               1        1
# 6fPQJq4f_yiq1NHn0fd11Q            1             0               0        0
# k-dDZvTeLysoJvjHI-qr9g            1             0               0        0
# MhnihE0alud0ereVInSt8Q            1             0               0        0
# i6hWP3si97eKQl_JyK8L3w            0             0               0        0
#
#                         Sandwiches  Breakfast & Brunch  ...  Pharmacy  \
# business_id                                             ...
# jScBTQtdAt-8RshaiBEHgw           1                   1  ...         0
# 6fPQJq4f_yiq1NHn0fd11Q           0                   0  ...         0
# k-dDZvTeLysoJvjHI-qr9g           0                   0  ...         0
# MhnihE0alud0ereVInSt8Q           0                   0  ...         0
# i6hWP3si97eKQl_JyK8L3w           0                   0  ...         0
#
#                         Funeral Services & Cemeteries  Popcorn Shops  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                              0              0
# 6fPQJq4f_yiq1NHn0fd11Q                              0              0
# k-dDZvTeLysoJvjHI-qr9g                              0              0
# MhnihE0alud0ereVInSt8Q                              0              0
# i6hWP3si97eKQl_JyK8L3w                              0              0
#
#                         Maternity Wear  Hotel bar  Venezuelan  Gold Buyers  \
# business_id
# jScBTQtdAt-8RshaiBEHgw               0          0           0            0
# 6fPQJq4f_yiq1NHn0fd11Q               0          0           0            0
# k-dDZvTeLysoJvjHI-qr9g               0          0           0            0
# MhnihE0alud0ereVInSt8Q               0          0           0            0
# i6hWP3si97eKQl_JyK8L3w               0          0           0            0
#
#                         Cigar Bars  Junk Removal & Hauling  Climbing
# business_id
# jScBTQtdAt-8RshaiBEHgw           0                       0         0
# 6fPQJq4f_yiq1NHn0fd11Q           0                       0         0
# k-dDZvTeLysoJvjHI-qr9g           0                       0         0
# MhnihE0alud0ereVInSt8Q           0                       0         0
# i6hWP3si97eKQl_JyK8L3w           0                       0         0
#
# [5 rows x 758 columns]

# %%
print('Number of categories:', categories.shape[1])
# Out:
# Number of categories: 758

# %% [markdown]
# We have increased dimensionality of our dataset. In order to reduce the dimensions, we couldcluster them in bigger buckets and modify the granularity of the features. However, it proves to be untractable and difficult to implement. We will see how the model behaves with this curse of dimensionality.

# %%
# building similarity matrix for all business
similarities = cosine_similarity(categories)
similarities = pd.DataFrame(similarities, 
                                 index=categories.index, 
                                 columns=categories.index)
similarities.head()
# Out:
# business_id             jScBTQtdAt-8RshaiBEHgw  6fPQJq4f_yiq1NHn0fd11Q  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                1.000000                0.174078
# 6fPQJq4f_yiq1NHn0fd11Q                0.174078                1.000000
# k-dDZvTeLysoJvjHI-qr9g                0.213201                0.408248
# MhnihE0alud0ereVInSt8Q                0.213201                0.408248
# i6hWP3si97eKQl_JyK8L3w                0.000000                0.000000
#
# business_id             k-dDZvTeLysoJvjHI-qr9g  MhnihE0alud0ereVInSt8Q  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                0.213201                0.213201
# 6fPQJq4f_yiq1NHn0fd11Q                0.408248                0.408248
# k-dDZvTeLysoJvjHI-qr9g                1.000000                0.500000
# MhnihE0alud0ereVInSt8Q                0.500000                1.000000
# i6hWP3si97eKQl_JyK8L3w                0.000000                0.000000
#
# business_id             i6hWP3si97eKQl_JyK8L3w  -ucQnELMVRIUOi3-Kv5r0Q  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                     0.0                0.000000
# 6fPQJq4f_yiq1NHn0fd11Q                     0.0                0.000000
# k-dDZvTeLysoJvjHI-qr9g                     0.0                0.000000
# MhnihE0alud0ereVInSt8Q                     0.0                0.000000
# i6hWP3si97eKQl_JyK8L3w                     1.0                0.471405
#
# business_id             mofOjB6flg-eAWOFbOkHfQ  QAqm1ubKgPYYqjZKxfi87A  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                0.134840                     0.0
# 6fPQJq4f_yiq1NHn0fd11Q                0.258199                     0.0
# k-dDZvTeLysoJvjHI-qr9g                0.632456                     0.0
# MhnihE0alud0ereVInSt8Q                0.632456                     0.0
# i6hWP3si97eKQl_JyK8L3w                0.000000                     0.0
#
# business_id             NX1281ugzs2navHAX5X9cQ  2tE_n3ws4Vn1byejSZZIsQ  ...  \
# business_id                                                             ...
# jScBTQtdAt-8RshaiBEHgw                0.269680                     0.0  ...
# 6fPQJq4f_yiq1NHn0fd11Q                0.258199                     0.0  ...
# k-dDZvTeLysoJvjHI-qr9g                0.316228                     0.0  ...
# MhnihE0alud0ereVInSt8Q                0.316228                     0.0  ...
# i6hWP3si97eKQl_JyK8L3w                0.000000                     0.0  ...
#
# business_id             wHn5jKZc3lt_Cu8uoBblgw  QkDhw-fQi_IijlqSnV3eIg  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                     0.0                     0.0
# 6fPQJq4f_yiq1NHn0fd11Q                     0.0                     0.0
# k-dDZvTeLysoJvjHI-qr9g                     0.0                     0.0
# MhnihE0alud0ereVInSt8Q                     0.0                     0.0
# i6hWP3si97eKQl_JyK8L3w                     0.0                     0.0
#
# business_id             JKmhHlmboFEsSSxPcYwxww  P_1ojkLpCsM8cpuiKlZnAg  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                     0.0                0.213201
# 6fPQJq4f_yiq1NHn0fd11Q                     0.0                0.000000
# k-dDZvTeLysoJvjHI-qr9g                     0.0                0.000000
# MhnihE0alud0ereVInSt8Q                     0.0                0.000000
# i6hWP3si97eKQl_JyK8L3w                     0.0                0.000000
#
# business_id             Lhl72icGvaW2rFClTy-hog  6Sd4KBcAwWKrpUEv4M_oIg  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                0.134840                     0.0
# 6fPQJq4f_yiq1NHn0fd11Q                0.258199                     0.0
# k-dDZvTeLysoJvjHI-qr9g                0.316228                     0.0
# MhnihE0alud0ereVInSt8Q                0.316228                     0.0
# i6hWP3si97eKQl_JyK8L3w                0.000000                     0.0
#
# business_id             HqvNxjGpLjfv9KgF-0OqPg  P8uECqGqXWTwEndkh-6bQw  \
# business_id
# jScBTQtdAt-8RshaiBEHgw                     0.0                0.269680
# 6fPQJq4f_yiq1NHn0fd11Q                     0.0                0.258199
# k-dDZvTeLysoJvjHI-qr9g                     0.0                0.316228
# MhnihE0alud0ereVInSt8Q                     0.0                0.316228
# i6hWP3si97eKQl_JyK8L3w                     0.0                0.000000
#
# business_id             2JsLzYF8rUalwpm5LDEcog  shIPnFoXrL3dFo5HLH1_HA
# business_id
# jScBTQtdAt-8RshaiBEHgw                0.174078                     0.0
# 6fPQJq4f_yiq1NHn0fd11Q                0.333333                     0.0
# k-dDZvTeLysoJvjHI-qr9g                0.408248                     0.0
# MhnihE0alud0ereVInSt8Q                0.408248                     0.0
# i6hWP3si97eKQl_JyK8L3w                0.000000                     0.0
#
# [5 rows x 4996 columns]

# %%
# Creating category based prediction function
def category_based(user_id, business_id, k=5):
         
    # Build similarity scores between last business and all the businesses the user already rated
    other_business_rated = ratings[ratings['user_id'] == user_id].iloc[1:]['business_id']
    business_sim = pd.Series(index=other_business_rated.index)
    for i in other_business_rated.index:
        business_sim.loc[i] = similarities.loc[business_id, other_business_rated[i]]

    # Get all the other businesses ratings for the user
    other_business_ratings = ratings[ratings['user_id'] == user_id].iloc[1:]['rating']

    # take k nearest neighbors
    k_index = other_business_ratings.sort_values(ascending=False).iloc[:k].index

    # Compute the predicted rating
    simTotal, weightedSum = 0, 0    
    
    for neighbor in k_index:
        simTotal += abs(business_sim[neighbor])
        weightedSum += business_sim[neighbor] * other_business_ratings[neighbor]
    if simTotal > 0:
        return weightedSum / simTotal
    else:
        # ratings mean
        return ratings['rating'].mean()

# %% [markdown]
# Let us now use our model to predict the last ratings of the users in our dataset:

# %%
last_ratings = ratings.drop_duplicates(subset='user_id', keep='first')
last_ratings.head()
# Out:
#                   user_id             business_id  rating                 date
# 0  keBv05MsMFBd0Hu98vXThQ  JDZ6_yycNQFTpUZzLIKHUg     5.0  2018-11-14 18:05:34
# 1  hZ_ElhGO3sQDVvM8ZrQetA  zfyGTLKOZuVY8aRoInyx9Q     4.0  2018-11-14 17:59:07
# 2  y5zqSJE-rFihsKmUZRbbRg  evdJO0v9rvVixieNEnaeJg     5.0  2018-11-14 17:57:01
# 3  ozUsNrw9QlEtz_JqN5PlMw  u1fa8SE-Rzea_xWbk_B-Zw     3.0  2018-11-14 17:49:52
# 4  sHY6JcgWOHLP4vR836Esmw  urSuLlkYXXI5uwtKIxl9ew     5.0  2018-11-14 17:25:32

# %%
# Computing predictions for last rating of each user 
predictions_user_based =[]
for row in tqdm(last_ratings.index):        
    user_id = last_ratings.loc[row, 'user_id']
    business_id = last_ratings.loc[row, 'business_id']
    prediction = category_based(user_id, business_id)
    predictions_user_based.append(prediction)

last_ratings['prediction'] = predictions_user_based

# Running time: 18'12
# Out:
# 100%|██████████| 30750/30750 [15:10<00:00, 33.78it/s]
# /Users/Jeremy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
last_ratings
# Out:
#                        user_id             business_id  rating  \
# 0       keBv05MsMFBd0Hu98vXThQ  JDZ6_yycNQFTpUZzLIKHUg     5.0
# 1       hZ_ElhGO3sQDVvM8ZrQetA  zfyGTLKOZuVY8aRoInyx9Q     4.0
# 2       y5zqSJE-rFihsKmUZRbbRg  evdJO0v9rvVixieNEnaeJg     5.0
# 3       ozUsNrw9QlEtz_JqN5PlMw  u1fa8SE-Rzea_xWbk_B-Zw     3.0
# 4       sHY6JcgWOHLP4vR836Esmw  urSuLlkYXXI5uwtKIxl9ew     5.0
# 5       SVC0CajvmYfH5uAq4JnGvg  OSF8Iy5Xq-hAN4-zhDVS4w     5.0
# 7       xqUn2yqxQRq5MrthbRb-7Q  syBbYNE5-rWDMOs-MkFRQw     5.0
# 8       3iaQRn8gPiuarpYmv9dOJA  G8vA6pq4p8KslaURm-q65Q     5.0
# 9       1Ay0chgeSlxCNcT2PLSBOg  -v8Z3mdbbPs1ljLziHr2DA     5.0
# 10      khC-KFL_z77NwaQXyoDBGQ  mwE5uNVkxCXvEuVa1KQ_3g     5.0
# 11      xO3EIJR0QNzM3CdajinWtw  j9d1c73emq6sL0v5IfrC-w     4.0
# 12      zbahX7xiLbjWWM4_L43lhg  ml916FaOdF870Jrk0ZQETA     3.0
# 13      aV3_VSE1ILtGsWeN74w6GQ  VgWvHMs5TJ2lr0ec2DaMtQ     3.0
# 14      62GNFh5FySkA3MbrQmnqvg  MVHaUexefp1XbqDw0_YYqQ     4.0
# 15      2jKzO_01d12oiu-2bOYcYg  mIVfDS47YwXjDjXVxAoZVg     5.0
# 16      7PHHxsjyk7I7oM6ENxwZZQ  nZDmR6dJYgeG9dAaUMlSbw     5.0
# 17      s76BDmBx_8kcxGFDiU6k_g  8h5C4aF_MIwlLBc9JtaD7Q     4.0
# 18      T28Y7AsnZftJptuiIQ_x6Q  0sPOBQHlVvuhO1h-1p1ccQ     3.0
# 19      cImvLb3Wvd5EZ8SRjKAPsw  MLVBJjbgk3sLZYyxqBD4XA     3.0
# 20      7q1EFKcjUTQhUrmjY2ZRkw  S1Gpj_cqlEzitBCGAXj5aA     5.0
# 21      GoARWqayYXgYsW1cKTi4Mg  MM8n7SPaIuMlDGbUM5SZhA     1.0
# 22      HcC-EdNjPu1Fh4dims7Dvg  OYle0xyj_qYZUPCrWfUu_A     5.0
# 23      fgwI3rYHOv1ipfVfCSx7pg  GKK0iaO5Ua3yeT_KFh0ICQ     5.0
# 24      _ZMD-Abvm-DHCmsOF-f8FA  sP3MY-Tyn2MxOj7E84-V7w     1.0
# 25      Fq8IobqhtJ1a8Q-Lb8B-LA  lIEahf71RLPJ_rFBJ5fqzQ     3.0
# 26      skTNZm-PocYP9hu-KajqNQ  079CV1EE5WLdQqVEVYFeHQ     5.0
# 27      SPZcg_4iu35i-MeMY0e5Mw  Azy2vmC47uHSkZE2fdvBjA     3.0
# 28      k58KNO8Rya-q8njKq8-uBQ  0Yh6U06nGLjAMwCw6l9-DA     2.0
# 29      8drMKNHWavs2g6uf0pLtvg  JhLnkKRtc7Ukt6FZUsyhdA     4.0
# 30      fSDE-rRJr0-cSorhNzy4pg  Azy2vmC47uHSkZE2fdvBjA     4.0
# ...                        ...                     ...     ...
# 316053  ctsKWK7PslV4O_zAOpPf2w  UY13CTgUqriT-fMxT2APLw     4.0
# 316120  3SRhLkjNr9Zm2XQ3NvMMBg  m9iqRUgclcsQs-z8c2FTeA     4.0
# 316148  IDVX4Is4CanREchBmpFXoA  Wxxvi3LZbHNIDwJ-ZimtnA     5.0
# 316166  aqWXHhcR_CdmKmxggFOlEA  d_L-rfS1vT3JMzgCUGtiow     2.0
# 316210  Xj9-p-_zm37ALyR1Qq34fQ  Zoowy70HwGUEsMD9qNlF4Q     5.0
# 316221  VeYSD3Xgxd-R4yowet51tA  UYTk8jS8uD2FddQIftWTHg     3.0
# 316256  unJsPznjZ5DUXqJgoPvmkg  makqSKZaz1aUipoWBW0BsA     2.0
# 316270  3xhIAIzNPhFAp24U3oCB1Q  ekdXu37aegXyIE2OhP2fQw     4.0
# 316440  RT8Y7PxPzC7DuAjAquNjng  dPFGRDC3Hsi1mDKxvKz_9Q     5.0
# 316490  dZBXRw0BtYd-C3MEjtHUFw  y3RlbCN0UrDdLnjSF9NkXA     4.0
# 316492  HLaSqQMDVvlcFPGJL_kGCA  Zzvjuyxr1iudPN_heAAygw     3.0
# 316501  iqF9DSNzYKPtPmBE5byK4g  zlFyjtCp4AQ1cPx59qeFQQ     5.0
# 316562  s9m1lSJyedtZRJSuQBE5HA  v50-nvBCZNf7nCNbyUlQLw     5.0
# 316566  T0C47-zkkVpyW6AUp3wzhg  apdb7MGnmnx6nGWBJ0ch_g     5.0
# 316592  Zr4N9sG31fybEa-l3a_46Q  d_L-rfS1vT3JMzgCUGtiow     3.0
# 316618  H42JuS0bQLf_G0iXeNUpwg  VxCnyVYn-FFgv6F1EqbdKA     2.0
# 316623  VQ-RXIZCH-7eRG8jSMmr9w  ECOkEVUodMLUxvI0PMI4gQ     5.0
# 316690  -IXvYa3uAcr68TeI0RzfWA  zlFyjtCp4AQ1cPx59qeFQQ     3.0
# 316763  RuqMLvQEYbPL06152nuLJw  d_L-rfS1vT3JMzgCUGtiow     4.0
# 316837  W92Wd0GE_-13ogVeKIIF7g  DxgSVufr_6y_Rc63CC17Zg     5.0
# 316916  H-LOkNSBBOrGPQOruqx74w  LwQB9H3jZ9wTk24Lr-AnZQ     3.0
# 316938  Zn7lIByuJmQQMVTK7rNAyQ  bp5ARRJu3_8CBsAS4tOWhA     1.0
# 316965  To7EBxWC-Yz011V2-tdTvA  OARQDsxyoGnnX2FfSl9HjA     5.0
# 316970  1h_UV-EwzmqZIB8uErf8ow  DxgSVufr_6y_Rc63CC17Zg     5.0
# 316971  _BR0kdjYQJVMyfGBKhKZPA  ECOkEVUodMLUxvI0PMI4gQ     4.0
# 317036  iw_6JAAw9FAIv2YkbLcMFA  zkhBU5qW_zCy0q4OEtIrsA     3.0
# 317070  06xIElWq6CAvmtk1xHJWNA  VxCnyVYn-FFgv6F1EqbdKA     4.0
# 317103  OXIJVK12GNTdHlmKJR7xbg  SvHAczHxIJ00QlJ9ovQR8g     5.0
# 317108  VnlUnPrfae-fbqDoXuvDbw  MjAuGkgPjNLyMrN74_0YbA     4.0
# 317115  _BHTC7nyCBoZcfiiD5cOXg  ZjdcfPbkBVtMnXm8jLSV_A     4.0
#
#                        date  prediction
# 0       2018-11-14 18:05:34    5.000000
# 1       2018-11-14 17:59:07    5.000000
# 2       2018-11-14 17:57:01    5.000000
# 3       2018-11-14 17:49:52    3.794692
# 4       2018-11-14 17:25:32    5.000000
# 5       2018-11-14 17:23:06    5.000000
# 7       2018-11-14 16:54:06    5.000000
# 8       2018-11-14 16:36:49    3.743222
# 9       2018-11-14 16:22:29    5.000000
# 10      2018-11-14 16:10:22    5.000000
# 11      2018-11-14 15:59:46    4.407413
# 12      2018-11-14 15:57:12    5.000000
# 13      2018-11-14 15:54:57    3.274292
# 14      2018-11-14 15:09:22    4.454134
# 15      2018-11-14 15:08:37    5.000000
# 16      2018-11-14 15:02:40    5.000000
# 17      2018-11-14 14:57:12    5.000000
# 18      2018-11-14 12:12:05    4.192793
# 19      2018-11-14 09:17:38    5.000000
# 20      2018-11-14 09:05:57    5.000000
# 21      2018-11-14 06:40:05    5.000000
# 22      2018-11-14 06:08:03    3.794692
# 23      2018-11-14 05:37:02    5.000000
# 24      2018-11-14 05:27:07    3.794692
# 25      2018-11-14 05:20:38    4.032106
# 26      2018-11-14 05:18:21    5.000000
# 27      2018-11-14 04:33:18    5.000000
# 28      2018-11-14 03:57:48    4.483315
# 29      2018-11-14 03:52:48    3.794692
# 30      2018-11-14 03:51:15    3.668883
# ...                     ...         ...
# 316053  2007-06-15 23:32:49    3.193186
# 316120  2007-05-31 06:50:10    3.000000
# 316148  2007-05-22 20:46:28    3.955593
# 316166  2007-05-15 06:02:43    4.304856
# 316210  2007-04-26 06:40:18    5.000000
# 316221  2007-04-19 21:46:52    5.000000
# 316256  2007-04-10 08:47:24    3.451750
# 316270  2007-04-04 00:54:32    5.000000
# 316440  2007-02-27 20:33:21    5.000000
# 316490  2007-02-15 18:41:23    3.284928
# 316492  2007-02-14 21:23:08    3.818871
# 316501  2007-02-12 18:35:51    3.000000
# 316562  2007-01-30 03:47:30    4.828231
# 316566  2007-01-29 21:56:26    3.298385
# 316592  2007-01-24 06:12:25    4.508441
# 316618  2007-01-17 08:34:49    4.208771
# 316623  2007-01-15 07:48:50    4.081227
# 316690  2006-12-03 03:40:50    3.274423
# 316763  2006-10-10 02:34:04    3.415064
# 316837  2006-08-30 19:26:33    3.794692
# 316916  2006-07-07 21:38:52    3.000000
# 316938  2006-06-24 22:21:12    4.000000
# 316965  2006-05-09 07:22:27    4.825233
# 316970  2006-04-26 00:27:41    2.000000
# 316971  2006-04-25 07:54:43    2.766968
# 317036  2006-02-06 01:23:27    2.358779
# 317070  2006-01-10 08:50:38    3.794692
# 317103  2005-12-25 01:28:45    4.000000
# 317108  2005-12-15 03:43:44    4.574645
# 317115  2005-11-25 17:16:39    5.000000
#
# [30750 rows x 5 columns]

# %%
# Accuracy
print('RMSE:', np.sqrt(mean_squared_error(last_ratings['rating'], last_ratings['prediction'])))
print('MAE:', mean_absolute_error(last_ratings['rating'], last_ratings['prediction']))
# Out:
# RMSE: 1.4202680669143533
# MAE: 1.0387913730607607

# %% [markdown]
# We can observe that the **RMSE obtained is lower than the one of our baseline on the same dataset**. One reason could be caused by the curse of dimensionality: a one-hot-encoding that yielded a highly dimensional dataset with more than six hundred categories. A lot of these categories could be highly correlated and have nefarious impact on the model performance.

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can observe that the RMSE obtained is relatively lower than our baselines'. There are unaccurate predictions. To improve our results, we could refine the categories data by clustering categories in bigger buckets, or  removing those that do not hold information or are highly correlated. Moreover, expanding the number of relevant attributes may also help.
